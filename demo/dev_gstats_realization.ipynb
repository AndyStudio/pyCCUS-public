# %%
import skgstat as skg
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('ggplot')

# %%
data = skg.data.pancake(N=500, seed=42)

# %%
coordinates, values = data.get('sample')

# %%
V = skg.Variogram(coordinates=coordinates, values=values)

# %%
V.plot()
# Out:
# /Applications/anaconda3/envs/gstat/lib/python3.10/site-packages/skgstat/plotting/variogram_plot.py:123: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
